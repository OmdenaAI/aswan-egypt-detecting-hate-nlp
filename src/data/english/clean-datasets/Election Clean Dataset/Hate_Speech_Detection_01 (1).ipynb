# %% [markdown]
# # Download Dataset to Content

# %%
# !wget https://www.romanklinger.de/data-sets/GrimmingerKlingerWASSA2021.zip
# Out:
# --2023-02-08 07:05:28--  https://www.romanklinger.de/data-sets/GrimmingerKlingerWASSA2021.zip
# Resolving www.romanklinger.de (www.romanklinger.de)... 51.75.78.158
# Connecting to www.romanklinger.de (www.romanklinger.de)|51.75.78.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 383645 (375K) [application/zip]
# Saving to: ‘GrimmingerKlingerWASSA2021.zip’
#
# GrimmingerKlingerWA 100%[===================>] 374.65K   597KB/s    in 0.6s
#
# 2023-02-08 07:05:30 (597 KB/s) - ‘GrimmingerKlingerWASSA2021.zip’ saved [383645/383645]

# %% [markdown]
# # Unzip Dataset

# %%
!7za x /content/GrimmingerKlingerWASSA2021.zip
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 383645 bytes (375 KiB)
#
# Extracting archive: /content/GrimmingerKlingerWASSA2021.zip
# --
# Path = /content/GrimmingerKlingerWASSA2021.zip
# Type = zip
# Physical Size = 383645
#
# Everything is Ok
#
# Files: 4
# Size:       816853
# Compressed: 383645

# %% [markdown]
# # Importing all Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import string
import nltk
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from bs4 import BeautifulSoup
import re,string,unicodedata
from keras.preprocessing import text, sequence
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from string import punctuation
import keras
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM,Dropout,Bidirectional,GRU
import tensorflow as tf

# %%
dfraw=pd.read_csv('train.tsv',sep='\t')

# %%
dfraw.head()
# Out:
#                                                 text             Trump  \
# 0  @SukiRavan @ProgressPotato @MarkZuckerb0rg @JS...           Neither
# 1  @Newsweek Are you freaking crazy????[NEWLINE]I...           Neither
# 2  Undecided voters (and MAGATs alike);[NEWLINE]I...           Against
# 3  @cheaterwins @Hungry_For_More @DAYSORSHAY So a...             Favor
# 4  @CNN Nancy Pelosi and the Dems wont do a deal ...  Neutral mentions
#
#               Biden     West          HOF
# 0             Favor  Neither  Non-Hateful
# 1             Favor  Neither  Non-Hateful
# 2  Neutral mentions  Neither  Non-Hateful
# 3  Neutral mentions  Neither  Non-Hateful
# 4           Neither  Neither  Non-Hateful

# %%
dfraw['HOF'].unique()
# Out:
# array(['Non-Hateful', 'Hateful'], dtype=object)

# %%
dfraw.shape
# Out:
# (2400, 5)

# %%
df=dfraw.copy()

# %% [markdown]
# # Remove All Stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)

# %% [markdown]
# # Remove HTTPS

# %%
import re
df['text'] = df['text'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
df
# Out:
#                                                    text             Trump  \
# 0     @SukiRavan @ProgressPotato @MarkZuckerb0rg @JS...           Neither
# 1     @Newsweek Are you freaking crazy????[NEWLINE]I...           Neither
# 2     Undecided voters (and MAGATs alike);[NEWLINE]I...           Against
# 3     @cheaterwins @Hungry_For_More @DAYSORSHAY So a...             Favor
# 4     @CNN Nancy Pelosi and the Dems wont do a deal ...  Neutral mentions
# ...                                                 ...               ...
# 2395  Just lost a ton of followers again. Looks like...             Favor
# 2396  @NovumQuid @OpenMothersMale @MikeSington I hav...           Neither
# 2397  @TheLeoTerrell @SenatorLoeffler @realDonaldTru...             Favor
# 2398  It’s too bad that at a time when we’re unemplo...           Neither
# 2399  @WhiteHouse @realDonaldTrump Trump's indiffere...           Against
#
#                  Biden     West          HOF
# 0                Favor  Neither  Non-Hateful
# 1                Favor  Neither  Non-Hateful
# 2     Neutral mentions  Neither  Non-Hateful
# 3     Neutral mentions  Neither  Non-Hateful
# 4              Neither  Neither  Non-Hateful
# ...                ...      ...          ...
# 2395           Neither  Neither  Non-Hateful
# 2396             Mixed  Neither  Non-Hateful
# 2397           Neither  Neither  Non-Hateful
# 2398             Favor  Neither  Non-Hateful
# 2399             Favor  Neither  Non-Hateful
#
# [2400 rows x 5 columns]

# %% [markdown]
# # Data Cleaning

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)
# Removing URL's
def remove_between_square_brackets(text):
    return re.sub(r'http\S+', '', text)
#Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop:
            final_text.append(i.strip())
    return " ".join(final_text)

# Remove Accented Chars
def remove_accented_chars_func(text):
    '''
    Removes all accented characters from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without accented characters
    '''
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
# Remove punctuation
def remove_punctuation_func(text):
    '''
    Removes all punctuation from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without punctuations
    '''
    return re.sub(r'[^a-zA-Z0-9]', ' ', text)
# Remove Irrelevant Char
def remove_irr_char_func(text):
    '''
    Removes all irrelevant characters (numbers and punctuation) from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without irrelevant characters
    '''
    return re.sub(r'[^a-zA-Z]', ' ', text)
#Remove Whitespaces
def remove_extra_whitespaces_func(text):
    '''
    Removes extra whitespaces from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without extra whitespaces
    ''' 
    return re.sub(r'^\s*|\s\s*', ' ', text).strip()
#lemmatization
#Removing the noisy text
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = remove_stopwords(text)
    text=remove_accented_chars_func(text)
    text=remove_punctuation_func(text)
    text=remove_irr_char_func(text)
    text=remove_extra_whitespaces_func(text)
    return text
#Apply function on review column
df['text']=df['text'].apply(denoise_text)

df
# Out:
#                                                    text             Trump  \
# 0     SukiRavan ProgressPotato MarkZuckerb rg JSiffo...           Neither
# 1     Newsweek freaking crazy NEWLINE Id rather watc...           Neither
# 2     Undecided voters and MAGATs alike NEWLINE If w...           Against
# 3     cheaterwins Hungry For More DAYSORSHAY right P...             Favor
# 4     CNN Nancy Pelosi Dems wont deal would make Tru...  Neutral mentions
# ...                                                 ...               ...
# 2395  lost ton followers again Looks like Im part Tw...             Favor
# 2396  NovumQuid OpenMothersMale MikeSington Delaware...           Neither
# 2397  TheLeoTerrell SenatorLoeffler realDonaldTrump ...             Favor
# 2398  Its bad time were unemployed government wont h...           Neither
# 2399  WhiteHouse realDonaldTrump Trump s indifferenc...           Against
#
#                  Biden     West          HOF
# 0                Favor  Neither  Non-Hateful
# 1                Favor  Neither  Non-Hateful
# 2     Neutral mentions  Neither  Non-Hateful
# 3     Neutral mentions  Neither  Non-Hateful
# 4              Neither  Neither  Non-Hateful
# ...                ...      ...          ...
# 2395           Neither  Neither  Non-Hateful
# 2396             Mixed  Neither  Non-Hateful
# 2397           Neither  Neither  Non-Hateful
# 2398             Favor  Neither  Non-Hateful
# 2399             Favor  Neither  Non-Hateful
#
# [2400 rows x 5 columns]

# %% [markdown]
# # Split Concantenated Words

# %%
# !pip install wordninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wordninja
#   Downloading wordninja-2.0.0.tar.gz (541 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.6/541.6 KB 14.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wordninja
#   Building wheel for wordninja (setup.py) ... done
#   Created wheel for wordninja: filename=wordninja-2.0.0-py3-none-any.whl size=541552 sha256=a7f81f686450bb24462ced5cba2c9cca5c05ee4cf0f11d9ce9f136436de76dae
#   Stored in directory: /root/.cache/pip/wheels/a6/08/fb/98831d1c2702c8352a339f91104515eab5d7906d4118eeeaed
# Successfully built wordninja
# Installing collected packages: wordninja
# Successfully installed wordninja-2.0.0

# %%
import wordninja

# %%
def split_text(text):
    split_words = wordninja.split(text)
    return ' '.join(split_words)

# %%
df['split_text'] = df['text'].apply(split_text)

# %%
df
# Out:
#                                                    text             Trump  \
# 0     SukiRavan ProgressPotato MarkZuckerb rg JSiffo...           Neither
# 1     Newsweek freaking crazy NEWLINE Id rather watc...           Neither
# 2     Undecided voters and MAGATs alike NEWLINE If w...           Against
# 3     cheaterwins Hungry For More DAYSORSHAY right P...             Favor
# 4     CNN Nancy Pelosi Dems wont deal would make Tru...  Neutral mentions
# ...                                                 ...               ...
# 2395  lost ton followers again Looks like Im part Tw...             Favor
# 2396  NovumQuid OpenMothersMale MikeSington Delaware...           Neither
# 2397  TheLeoTerrell SenatorLoeffler realDonaldTrump ...             Favor
# 2398  Its bad time were unemployed government wont h...           Neither
# 2399  WhiteHouse realDonaldTrump Trump s indifferenc...           Against
#
#                  Biden     West          HOF  \
# 0                Favor  Neither  Non-Hateful
# 1                Favor  Neither  Non-Hateful
# 2     Neutral mentions  Neither  Non-Hateful
# 3     Neutral mentions  Neither  Non-Hateful
# 4              Neither  Neither  Non-Hateful
# ...                ...      ...          ...
# 2395           Neither  Neither  Non-Hateful
# 2396             Mixed  Neither  Non-Hateful
# 2397           Neither  Neither  Non-Hateful
# 2398             Favor  Neither  Non-Hateful
# 2399             Favor  Neither  Non-Hateful
#
#                                              split_text
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...
# 1     Newsweek freaking crazy NEWLINE Id rather watc...
# 2     Undecided voters and MAG AT s a like NEWLINE I...
# 3     cheater wins Hungry For More DAYS OR SHAY righ...
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...
# ...                                                 ...
# 2395  lost ton followers again Looks like Im part Tw...
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...
# 2397  The Leo Terrell Senator Loe ff ler real Donald...
# 2398  Its bad time were unemployed government wont h...
# 2399  WhiteHouse real Donald Trump Trump s indiffere...
#
# [2400 rows x 6 columns]

# %% [markdown]
# # Lemmatization

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
  words = text.split()
  words = [lemmatizer.lemmatize(word,pos='v') for word in words]
  return ' '.join(words)
df['split_text'] = df['split_text'].apply(lemmatize_words)

df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#                                                    text             Trump  \
# 0     SukiRavan ProgressPotato MarkZuckerb rg JSiffo...           Neither
# 1     Newsweek freaking crazy NEWLINE Id rather watc...           Neither
# 2     Undecided voters and MAGATs alike NEWLINE If w...           Against
# 3     cheaterwins Hungry For More DAYSORSHAY right P...             Favor
# 4     CNN Nancy Pelosi Dems wont deal would make Tru...  Neutral mentions
# ...                                                 ...               ...
# 2395  lost ton followers again Looks like Im part Tw...             Favor
# 2396  NovumQuid OpenMothersMale MikeSington Delaware...           Neither
# 2397  TheLeoTerrell SenatorLoeffler realDonaldTrump ...             Favor
# 2398  Its bad time were unemployed government wont h...           Neither
# 2399  WhiteHouse realDonaldTrump Trump s indifferenc...           Against
#
#                  Biden     West          HOF  \
# 0                Favor  Neither  Non-Hateful
# 1                Favor  Neither  Non-Hateful
# 2     Neutral mentions  Neither  Non-Hateful
# 3     Neutral mentions  Neither  Non-Hateful
# 4              Neither  Neither  Non-Hateful
# ...                ...      ...          ...
# 2395           Neither  Neither  Non-Hateful
# 2396             Mixed  Neither  Non-Hateful
# 2397           Neither  Neither  Non-Hateful
# 2398             Favor  Neither  Non-Hateful
# 2399             Favor  Neither  Non-Hateful
#
#                                              split_text
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...
# 1     Newsweek freak crazy NEWLINE Id rather watch R...
# 2     Undecided voters and MAG AT s a like NEWLINE I...
# 3     cheater win Hungry For More DAYS OR SHAY right...
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...
# ...                                                 ...
# 2395  lose ton followers again Looks like Im part Tw...
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...
# 2397  The Leo Terrell Senator Loe ff ler real Donald...
# 2398  Its bad time be unemployed government wont hel...
# 2399  WhiteHouse real Donald Trump Trump s indiffere...
#
# [2400 rows x 6 columns]

# %%
dfclean=df.copy()

# %%
dfclean01=df[['split_text','HOF']]

# %%
dfclean01
# Out:
#                                              split_text          HOF
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...  Non-Hateful
# 1     Newsweek freak crazy NEWLINE Id rather watch R...  Non-Hateful
# 2     Undecided voters and MAG AT s a like NEWLINE I...  Non-Hateful
# 3     cheater win Hungry For More DAYS OR SHAY right...  Non-Hateful
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...  Non-Hateful
# ...                                                 ...          ...
# 2395  lose ton followers again Looks like Im part Tw...  Non-Hateful
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...  Non-Hateful
# 2397  The Leo Terrell Senator Loe ff ler real Donald...  Non-Hateful
# 2398  Its bad time be unemployed government wont hel...  Non-Hateful
# 2399  WhiteHouse real Donald Trump Trump s indiffere...  Non-Hateful
#
# [2400 rows x 2 columns]

# %%
dfclean01['Corpus Name']='Elections'
# Out:
# <ipython-input-25-a08c25805e6f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean01['Corpus Name']='Elections'

# %%
dfclean01
# Out:
#                                              split_text          HOF  \
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...  Non-Hateful
# 1     Newsweek freak crazy NEWLINE Id rather watch R...  Non-Hateful
# 2     Undecided voters and MAG AT s a like NEWLINE I...  Non-Hateful
# 3     cheater win Hungry For More DAYS OR SHAY right...  Non-Hateful
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...  Non-Hateful
# ...                                                 ...          ...
# 2395  lose ton followers again Looks like Im part Tw...  Non-Hateful
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...  Non-Hateful
# 2397  The Leo Terrell Senator Loe ff ler real Donald...  Non-Hateful
# 2398  Its bad time be unemployed government wont hel...  Non-Hateful
# 2399  WhiteHouse real Donald Trump Trump s indiffere...  Non-Hateful
#
#      Corpus Name
# 0      Elections
# 1      Elections
# 2      Elections
# 3      Elections
# 4      Elections
# ...          ...
# 2395   Elections
# 2396   Elections
# 2397   Elections
# 2398   Elections
# 2399   Elections
#
# [2400 rows x 3 columns]

# %%
dfclean01['raw_sentence']=dfraw['text']
# Out:
# <ipython-input-27-efdbde929584>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean01['raw_sentence']=dfraw['text']

# %%
dfclean01
# Out:
#                                              split_text          HOF  \
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...  Non-Hateful
# 1     Newsweek freak crazy NEWLINE Id rather watch R...  Non-Hateful
# 2     Undecided voters and MAG AT s a like NEWLINE I...  Non-Hateful
# 3     cheater win Hungry For More DAYS OR SHAY right...  Non-Hateful
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...  Non-Hateful
# ...                                                 ...          ...
# 2395  lose ton followers again Looks like Im part Tw...  Non-Hateful
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...  Non-Hateful
# 2397  The Leo Terrell Senator Loe ff ler real Donald...  Non-Hateful
# 2398  Its bad time be unemployed government wont hel...  Non-Hateful
# 2399  WhiteHouse real Donald Trump Trump s indiffere...  Non-Hateful
#
#      Corpus Name                                       raw_sentence
# 0      Elections  @SukiRavan @ProgressPotato @MarkZuckerb0rg @JS...
# 1      Elections  @Newsweek Are you freaking crazy????[NEWLINE]I...
# 2      Elections  Undecided voters (and MAGATs alike);[NEWLINE]I...
# 3      Elections  @cheaterwins @Hungry_For_More @DAYSORSHAY So a...
# 4      Elections  @CNN Nancy Pelosi and the Dems wont do a deal ...
# ...          ...                                                ...
# 2395   Elections  Just lost a ton of followers again. Looks like...
# 2396   Elections  @NovumQuid @OpenMothersMale @MikeSington I hav...
# 2397   Elections  @TheLeoTerrell @SenatorLoeffler @realDonaldTru...
# 2398   Elections  It’s too bad that at a time when we’re unemplo...
# 2399   Elections  @WhiteHouse @realDonaldTrump Trump's indiffere...
#
# [2400 rows x 4 columns]

# %%
dfclean02=dfclean01[['Corpus Name','raw_sentence']]

# %%
dfclean02['label']=dfclean01['HOF']
dfclean02
# Out:
# <ipython-input-30-27f3372ee2c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfclean02['label']=dfclean01['HOF']
#      Corpus Name                                       raw_sentence  \
# 0      Elections  @SukiRavan @ProgressPotato @MarkZuckerb0rg @JS...
# 1      Elections  @Newsweek Are you freaking crazy????[NEWLINE]I...
# 2      Elections  Undecided voters (and MAGATs alike);[NEWLINE]I...
# 3      Elections  @cheaterwins @Hungry_For_More @DAYSORSHAY So a...
# 4      Elections  @CNN Nancy Pelosi and the Dems wont do a deal ...
# ...          ...                                                ...
# 2395   Elections  Just lost a ton of followers again. Looks like...
# 2396   Elections  @NovumQuid @OpenMothersMale @MikeSington I hav...
# 2397   Elections  @TheLeoTerrell @SenatorLoeffler @realDonaldTru...
# 2398   Elections  It’s too bad that at a time when we’re unemplo...
# 2399   Elections  @WhiteHouse @realDonaldTrump Trump's indiffere...
#
#             label
# 0     Non-Hateful
# 1     Non-Hateful
# 2     Non-Hateful
# 3     Non-Hateful
# 4     Non-Hateful
# ...           ...
# 2395  Non-Hateful
# 2396  Non-Hateful
# 2397  Non-Hateful
# 2398  Non-Hateful
# 2399  Non-Hateful
#
# [2400 rows x 3 columns]

# %%
dfclean02['clean_sentence_training']=dfclean01['split_text']
dfclean02
# Out:
#      Corpus Name                                       raw_sentence  \
# 0      Elections  @SukiRavan @ProgressPotato @MarkZuckerb0rg @JS...
# 1      Elections  @Newsweek Are you freaking crazy????[NEWLINE]I...
# 2      Elections  Undecided voters (and MAGATs alike);[NEWLINE]I...
# 3      Elections  @cheaterwins @Hungry_For_More @DAYSORSHAY So a...
# 4      Elections  @CNN Nancy Pelosi and the Dems wont do a deal ...
# ...          ...                                                ...
# 2395   Elections  Just lost a ton of followers again. Looks like...
# 2396   Elections  @NovumQuid @OpenMothersMale @MikeSington I hav...
# 2397   Elections  @TheLeoTerrell @SenatorLoeffler @realDonaldTru...
# 2398   Elections  It’s too bad that at a time when we’re unemplo...
# 2399   Elections  @WhiteHouse @realDonaldTrump Trump's indiffere...
#
#             label                            clean_sentence_training
# 0     Non-Hateful  Suki Rav an Progress Potato Mark Zucker b rg J...
# 1     Non-Hateful  Newsweek freak crazy NEWLINE Id rather watch R...
# 2     Non-Hateful  Undecided voters and MAG AT s a like NEWLINE I...
# 3     Non-Hateful  cheater win Hungry For More DAYS OR SHAY right...
# 4     Non-Hateful  CNN Nancy Pelosi Dem s wont deal would make Tr...
# ...           ...                                                ...
# 2395  Non-Hateful  lose ton followers again Looks like Im part Tw...
# 2396  Non-Hateful  N ovum Quid Open Mothers Male Mike Sing ton De...
# 2397  Non-Hateful  The Leo Terrell Senator Loe ff ler real Donald...
# 2398  Non-Hateful  Its bad time be unemployed government wont hel...
# 2399  Non-Hateful  WhiteHouse real Donald Trump Trump s indiffere...
#
# [2400 rows x 4 columns]

# %%
dfclean02['clean_sentence_EDA']=dfclean01['split_text']
dfclean02
# Out:
#      Corpus Name                                       raw_sentence  \
# 0      Elections  @SukiRavan @ProgressPotato @MarkZuckerb0rg @JS...
# 1      Elections  @Newsweek Are you freaking crazy????[NEWLINE]I...
# 2      Elections  Undecided voters (and MAGATs alike);[NEWLINE]I...
# 3      Elections  @cheaterwins @Hungry_For_More @DAYSORSHAY So a...
# 4      Elections  @CNN Nancy Pelosi and the Dems wont do a deal ...
# ...          ...                                                ...
# 2395   Elections  Just lost a ton of followers again. Looks like...
# 2396   Elections  @NovumQuid @OpenMothersMale @MikeSington I hav...
# 2397   Elections  @TheLeoTerrell @SenatorLoeffler @realDonaldTru...
# 2398   Elections  It’s too bad that at a time when we’re unemplo...
# 2399   Elections  @WhiteHouse @realDonaldTrump Trump's indiffere...
#
#             label                            clean_sentence_training  \
# 0     Non-Hateful  Suki Rav an Progress Potato Mark Zucker b rg J...
# 1     Non-Hateful  Newsweek freak crazy NEWLINE Id rather watch R...
# 2     Non-Hateful  Undecided voters and MAG AT s a like NEWLINE I...
# 3     Non-Hateful  cheater win Hungry For More DAYS OR SHAY right...
# 4     Non-Hateful  CNN Nancy Pelosi Dem s wont deal would make Tr...
# ...           ...                                                ...
# 2395  Non-Hateful  lose ton followers again Looks like Im part Tw...
# 2396  Non-Hateful  N ovum Quid Open Mothers Male Mike Sing ton De...
# 2397  Non-Hateful  The Leo Terrell Senator Loe ff ler real Donald...
# 2398  Non-Hateful  Its bad time be unemployed government wont hel...
# 2399  Non-Hateful  WhiteHouse real Donald Trump Trump s indiffere...
#
#                                      clean_sentence_EDA
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...
# 1     Newsweek freak crazy NEWLINE Id rather watch R...
# 2     Undecided voters and MAG AT s a like NEWLINE I...
# 3     cheater win Hungry For More DAYS OR SHAY right...
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...
# ...                                                 ...
# 2395  lose ton followers again Looks like Im part Tw...
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...
# 2397  The Leo Terrell Senator Loe ff ler real Donald...
# 2398  Its bad time be unemployed government wont hel...
# 2399  WhiteHouse real Donald Trump Trump s indiffere...
#
# [2400 rows x 5 columns]

# %% [markdown]
# # Label Encoding the label

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
le = LabelEncoder()

# Fit the encoder to the dataframe column
le.fit(dfclean02['label'])

# Transform the column and replace it in the dataframe
dfclean02['label'] = le.transform(dfclean02['label'])

# %%
dfclean02
# Out:
#      Corpus Name                                       raw_sentence  label  \
# 0      Elections  @SukiRavan @ProgressPotato @MarkZuckerb0rg @JS...      1
# 1      Elections  @Newsweek Are you freaking crazy????[NEWLINE]I...      1
# 2      Elections  Undecided voters (and MAGATs alike);[NEWLINE]I...      1
# 3      Elections  @cheaterwins @Hungry_For_More @DAYSORSHAY So a...      1
# 4      Elections  @CNN Nancy Pelosi and the Dems wont do a deal ...      1
# ...          ...                                                ...    ...
# 2395   Elections  Just lost a ton of followers again. Looks like...      1
# 2396   Elections  @NovumQuid @OpenMothersMale @MikeSington I hav...      1
# 2397   Elections  @TheLeoTerrell @SenatorLoeffler @realDonaldTru...      1
# 2398   Elections  It’s too bad that at a time when we’re unemplo...      1
# 2399   Elections  @WhiteHouse @realDonaldTrump Trump's indiffere...      1
#
#                                 clean_sentence_training  \
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...
# 1     Newsweek freak crazy NEWLINE Id rather watch R...
# 2     Undecided voters and MAG AT s a like NEWLINE I...
# 3     cheater win Hungry For More DAYS OR SHAY right...
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...
# ...                                                 ...
# 2395  lose ton followers again Looks like Im part Tw...
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...
# 2397  The Leo Terrell Senator Loe ff ler real Donald...
# 2398  Its bad time be unemployed government wont hel...
# 2399  WhiteHouse real Donald Trump Trump s indiffere...
#
#                                      clean_sentence_EDA
# 0     Suki Rav an Progress Potato Mark Zucker b rg J...
# 1     Newsweek freak crazy NEWLINE Id rather watch R...
# 2     Undecided voters and MAG AT s a like NEWLINE I...
# 3     cheater win Hungry For More DAYS OR SHAY right...
# 4     CNN Nancy Pelosi Dem s wont deal would make Tr...
# ...                                                 ...
# 2395  lose ton followers again Looks like Im part Tw...
# 2396  N ovum Quid Open Mothers Male Mike Sing ton De...
# 2397  The Leo Terrell Senator Loe ff ler real Donald...
# 2398  Its bad time be unemployed government wont hel...
# 2399  WhiteHouse real Donald Trump Trump s indiffere...
#
# [2400 rows x 5 columns]

# %%
dfclean02.to_csv('elections.csv')
