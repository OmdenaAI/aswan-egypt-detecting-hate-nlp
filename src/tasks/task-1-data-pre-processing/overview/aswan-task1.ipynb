# %% [markdown]
# # Omdena Aswan Project
# ## Pre-processed English data from task 1
#
# In what follows, I'll display all the files that were pre-processed during task 1 following the guidelines outlined by myself and Vishu Kalier.

# %%
import pandas as pd

# %% [markdown]
# ### Corpus: Hate Speech Dataset (Rubaiyat Islam)

# %%
corpus1 = pd.read_csv("Hate_speech_dataset_Twitter_sentiment_analysis.csv")
corpus1.sample(10)
# Out:
#        Unnamed: 0                                     corpus_name  \
# 25776       25776  hate_speech_dataset_twitter_sentiment_analysis
# 27326       27326  hate_speech_dataset_twitter_sentiment_analysis
# 25151       25151  hate_speech_dataset_twitter_sentiment_analysis
# 27995       27995  hate_speech_dataset_twitter_sentiment_analysis
# 26455       26455  hate_speech_dataset_twitter_sentiment_analysis
# 30862       30862  hate_speech_dataset_twitter_sentiment_analysis
# 842           842  hate_speech_dataset_twitter_sentiment_analysis
# 26602       26602  hate_speech_dataset_twitter_sentiment_analysis
# 15149       15149  hate_speech_dataset_twitter_sentiment_analysis
# 17480       17480  hate_speech_dataset_twitter_sentiment_analysis
#
#                                             raw_sentence  label  \
# 25776   @user @user #music #preorder time to spread t...      0
# 27326                       where to sta...ð¢ð¢ð¢       0
# ...

# %%
# display corpus shape

corpus1.shape
# Out:
# (31962, 6)

# %% [markdown]
# ### Corpus: Toxic Comment Classification Challenge (Hyacinth Ampadu)

# %%
corpus2 = pd.read_csv("Toxic_Comment_Classification_Challenge.csv")
corpus2.sample(10)
# Out:
#         Unnamed: 0                             corpus_name  \
# 9765          9765  Toxic Comment Classification Challenge
# 131237      131237  Toxic Comment Classification Challenge
# 191370      191370  Toxic Comment Classification Challenge
# 223109      223109  Toxic Comment Classification Challenge
# 125219      125219  Toxic Comment Classification Challenge
# 134359      134359  Toxic Comment Classification Challenge
# 36558        36558  Toxic Comment Classification Challenge
# 60445        60445  Toxic Comment Classification Challenge
# 167714      167714  Toxic Comment Classification Challenge
# 19443        19443  Toxic Comment Classification Challenge
#
#                                              raw_sentence  label  \
# 9765    I don't think Related Characters is the way to...      0
# 131237  "\n\nDiphenhydramine edit\n\nWhy was my edit i...      0
# 191370  ==Image== \n\n I recently uploaded File:Zayn a...      0
# ...

# %%
# display corpus shape

corpus2.shape
# Out:
# (223549, 6)

# %% [markdown]
# ### Corpora (multiple): Measuring Hate Speech, Hate Speech Offensive, Twitter Tweets Sentiment (Ameya Chaudhari, Christian De Los Santos)

# %%
corpus3 = pd.read_csv("clean_combined_dataset.csv")
corpus3.sample(10)
# Out:
#                                             raw sentence  \
# 42619  @user @user @user well miss marsh is definitel...
# 2977          @DatBoyRayT bitch ass nigga Rico &#128530;
# 35770   @user simple rules for a   life  #quotes #pos...
# 23324  You hoes AINT fucking with me &#128526;&#12852...
# 53350  (bankai fam #7) gstats - i get it on ( produce...
# 24652                                  what a retard lol
# 33903  #adobelife   buffalo simulation: buffalo for y...
# 18270  RT @_DalvinA: &#8220;@Can_iGet_8: I can't stan...
# 20430  RT @zLuketheDuke: @TonyJRodriguez just a bunch...
# 28608                           @user then why are you
#
#                                  clean sentence training  label  \
# 42619     powerful especially light recent terror attack    0.0
# 2977                                      shes bad bitch    1.0
# 35770                                   fathersday enjoy    0.0
# 23324  fuck fuck faggot ass randos even find zoe ask ...    2.0
# ...

# %%
corpus3.shape
# Out:
# (64598, 4)

# %% [markdown]
# ### Corpus: Hate Check Data (Caterina Bonan)

# %%
corpus4 = pd.read_csv("hatecheck-data-clean.csv")
corpus4.sample(10)
# Out:
#          corpus_name                                       raw_sentence  \
# 1591  hatecheck-data  Black people refuse to respect us. I'm going t...
# 2180  hatecheck-data  In my view, those kinds of disabled people oug...
# 640   hatecheck-data  We will keep attacking you black people until ...
# 362   hatecheck-data                  Your Muslim lives are worthless.
# 813   hatecheck-data  It's in everybody's interest to just slaughter...
# 2761  hatecheck-data   You have to stop calling immigrants disgusting.
# 1706  hatecheck-data         Immigrant lives are not worth protecting.
# 1752  hatecheck-data  It should be clear that black people are not h...
# 522   hatecheck-data  Never trust a single word said by a disabled p...
# 2912  hatecheck-data           Disgusted by all the mould around here.
#
#       label                            clean_sentence_training  \
# 1591      2  Black people refuse respect us  I m going make...
# ...

# %%
corpus4.shape
# Out:
# (3901, 5)

# %% [markdown]
# ### Corpus: Slur Corpus (Caterina Bonan)

# %%
corpus5 = pd.read_csv("slur-corpus-clean.csv")
corpus5.sample(10)
# Out:
#        corpus_name                                       raw_sentence  label  \
# 22196  slur-corpus  Omg thanks for backing me up dude these faggot...      0
# 631    slur-corpus  Well lets see ...its a WW2 game with a Women o...      0
# 17308  slur-corpus  Yes and no.\n\nIf a white person mimicking a J...      2
# 7948   slur-corpus   Fuck her already.  Oh, I forgot.  OP is a faggot      0
# 31214  slur-corpus  SJW mantra: If you don't agree with someone, d...      0
# 34271  slur-corpus  b..but it's the [CURRENT YEAR]! I thought all ...      0
# 22892  slur-corpus  People who support feminism are literally ugly...      2
# 9870   slur-corpus                                OP's BF is a faggot      2
# 12416  slur-corpus  But you could say the same about 'faggot'\n\nY...      0
# 21755  slur-corpus  You are an asshole, and not an asshole. Asshol...      0
#
#                                  clean_sentence_training  \
# 22196  Omg thanks backing dude faggots teaming I knew...
# ...

# %%
corpus5.shape
# Out:
# (37810, 5)

# %% [markdown]
# ### Corpus: Mendeley Hate Speech Dataset Part 1 (Muthukumaran Manickavasagam)
#
# The file does not follow the guidelines (3 columns). Disregard or re-do pre-processing.

# %%
corpus6 = pd.read_csv("clean_mendeley_hatespeech_dataset_partA.csv")
corpus6.sample(10)
# Out:
#         Unnamed: 0                                            content  label
# 127345      127345                       OK Ill take look Thanks note      0
# 71499        71499                         Why wiener small  It Asian      1
# 11920        11920  OK please explain opinion hate Serbs personal ...      0
# 209577      209577  As usual make lot remark reliable source The s...      0
# 243798      243798            If jew piece garbage hell care happened      1
# 23843        23843  Your attack clearly retaliation waring vandali...      0
# 84819        84819  Why Did delete post world famous Angler John B...      0
# 275389      275389  @user sadly international situation many ppl r...      0
# 78422        78422  From Halaqahs user page Christianity Slavery G...      0
# 218473      218473  @98Halima @BilalIGhumman @johnnygjokaj @cdnKha...      1

# %%
corpus6.shape
# Out:
# (280440, 3)

# %% [markdown]
# ###  Mendeley Hate Speech Dataset Part 2 (Muthukumaran Manickavasagam)
#
# The file does not follow the guidelines (3 columns). Disregard or re-do pre-processing.

# %%
corpus7 = pd.read_csv("clean_mendeley_hatespeech_dataset_partB.csv")
corpus7.sample(10)
# Out:
#         Unnamed: 0                                            content  label
# 147975      428415  Hi Miszawell I must say Im disappointed lack c...      0
# 71292       351732        Pier Gerlofs Donia Did know DYK Greate Pier      0
# 143167      423607  I made mistake reason inclusion table above Bu...      0
# 266823      547263  @user I wrote brain cell retard fucking blind ...      1
# 157075      437515                                   u guus foing yet      0
# 269670      550110                                       @user A cunt      1
# 186398      466838                     Democrats fucking party Karens      0
# 92748       373188  The RBA bound Reserve Bank Act  bank certain f...      0
# 158217      438657   My grandmother big bitch father fraking arsehole      0
# 113846      394286  So Barnstar Bundy living nickname thats real b...      0

# %%
corpus7.shape
# Out:
# (280439, 3)

# %% [markdown]
# ### Corpus: Abusive Swearing (Vishu Kalier)
#
# Delete 'tokenized' column.

# %%
corpus8 = pd.read_csv("PreprocessedII.csv")
corpus8.sample(10)
# Out:
#                                            raw_sentence       corpus_name  \
# 321   @USER shut the <b>fuck</b> upppp kliff i'm big...  Abusive_Swearing
# 881   @USER bitch i saw your whole ass tweet from we...  Abusive_Swearing
# 877   @USER What the <b>fuck</b> You don’t care abou...  Abusive_Swearing
# 461          @USER I ain’t <b>fucking</b> w/u today lol  Abusive_Swearing
# 491   @USER @USER @USER Gotta love when the uninform...  Abusive_Swearing
# 1395  #SesameStreet’s #Bert and #Ernie came out of t...  Abusive_Swearing
# 135   @USER This is not the first time she has expre...  Abusive_Swearing
# 1458  The blatant abuse of the #metoo is really dist...  Abusive_Swearing
# 479   @USER @USER @USER @USER @USER That's why I am ...  Abusive_Swearing
# 1479  @USER STOP LYING <b>asshole</b> FBI ISNT INVOL...  Abusive_Swearing
#
#                                 clean_sentence_training  \
# 321   shut fuck upppp kliff 'm bigger gayer n't try ...
# ...

# %%
corpus8.shape
# Out:
# (1511, 6)

# %% [markdown]
# ### Corpus: Dynamically Generated Hate Speech (Asma Merabet)

# %%
corpus9 = pd.read_csv("clean_dynamically-generated-hate-speech-dataset.csv")
corpus9.sample(10)
# Out:
#                              corpus_name  \
# 979    Dynamically Generated Hate Speech
# 11078  Dynamically Generated Hate Speech
# 8900   Dynamically Generated Hate Speech
# 14706  Dynamically Generated Hate Speech
# 8190   Dynamically Generated Hate Speech
# 11577  Dynamically Generated Hate Speech
# 5770   Dynamically Generated Hate Speech
# 7791   Dynamically Generated Hate Speech
# 30790  Dynamically Generated Hate Speech
# 27838  Dynamically Generated Hate Speech
#
#                                             raw_sentence    label  \
# 979                       Attack any chinks that you see        2
# 11078  Everyone thinks that mulattos are amazing and ...        2
# 8900   I love that I dont have to work with customer...  nothate
# 14706                Piers Morgan should no longer exist  nothate
# 8190                       So happy to be a black nigga!  nothate
# 11577  I'm not going to let a muslim ruin my life, le...        2
# ...

# %%
corpus9.shape
# Out:
# (40787, 5)

# %% [markdown]
# ### Corpus: A Benchmark Dataset for Learning to Intervene in Online Hate Speech (Aya Abdalsalam)
#
# Only 3 columns - modify or disregard.

# %%
corpus10 = pd.read_csv("A-Benchmark-Dataset-for-Learning-to-Intervene-in-Online-Hate-Speech.csv")
corpus10.sample(10)
# Out:
#        Unnamed: 0                                               text  label
# 9423         9423  Liberal feminist woman dont give one single fu...      1
# 5898         5898  rejection left GLOBALGET BOARD Yes Communist L...      1
# 10949       10949  insult check mark like discriminated giving To...      1
# 4870         4870  New York City Legalizes Third Gender X Birth C...      0
# 9773         9773  RT townhallcom McCaskill Want James OKeefe Inv...      0
# 1318         1318  Something something bout free speech something...      0
# 11240       11240  Thirtythree minute phone order two part Genera...      1
# 11237       11237  rambling Update account active yea trolling de...      2
# 4172         4172  Black father child White woman active child ’ ...      1
# 12481       12481  Well look like nigger around dick breath Besid...      0

# %%
corpus10.shape
# Out:
# (14743, 3)

# %% [markdown]
# ### Corpus: Malignant Comment Classification (Vishu Kalier)

# %%
corpus11 = pd.read_csv("malignant_comments_clean.csv")
corpus11.sample(10)
# Out:
#                              corpus_name  \
# 88803   Malignant_Comment_Classification
# 96888   Malignant_Comment_Classification
# 78030   Malignant_Comment_Classification
# 48873   Malignant_Comment_Classification
# 126569  Malignant_Comment_Classification
# 133888  Malignant_Comment_Classification
# 157962  Malignant_Comment_Classification
# 42683   Malignant_Comment_Classification
# 36051   Malignant_Comment_Classification
# 80507   Malignant_Comment_Classification
#
#                                              raw_sentence  \
# 88803   "\n\n Army Medical Services Museum branding eq...
# 96888   "\nOrphaned fair use image (Image:Freakum-dres...
# 78030   "\n\nI'm sorry I have to disagree and have vot...
# 48873   What you stated was a SPOILER. Do you also lik...
# 126569  If there was a cure for AIDs, it would probabl...
# 133888  A word of advice\n\nHallo Famekeeper, I see yo...
# 157962  """Would you agree there is nothing in your su...
# ...

# %%
corpus11.shape
# Out:
# (159571, 5)

# %% [markdown]
# # Corpus: Elections (Rian Rachmanto)
#
# Thelabels were not translated properly. Please modify.

# %%
corpus12 = pd.read_csv("elections.csv")
corpus12.sample(10)
# Out:
#       Unnamed: 0 Corpus Name  \
# 790          790   Elections
# 2384        2384   Elections
# 1738        1738   Elections
# 2016        2016   Elections
# 910          910   Elections
# 248          248   Elections
# 1300        1300   Elections
# 374          374   Elections
# 1782        1782   Elections
# 1808        1808   Elections
#
#                                            raw_sentence        label  \
# 790   Thank You. [NEWLINE][NEWLINE]Its [NEWLINE]#Tru...  Non-Hateful
# 2384  Thinking about all the people who talked shit ...  Non-Hateful
# 1738  I’d really like for Joe Biden and Kamala Harri...  Non-Hateful
# 2016  @mmpadellan A vote against Trump is more impor...  Non-Hateful
# 910   #2 ED I am said: To man All nation you was war...  Non-Hateful
# 248   Biden Refuses to Answer Whether He Plans on 'P...  Non-Hateful
# 1300  @RonBrownstein @gtconway3d @jmartNYT Last day ...  Non-Hateful
# 374   NEW: the second presidential debate, scheduled...  Non-Hateful
# ...

# %%
corpus12.shape
# Out:
# (2400, 6)

# %% [markdown]
# # Corpus: CONAN (Rajuta Karekar)

# %%
corpus13 = pd.read_csv("conan.dataset.labelled.csv")
corpus13.sample(10)
# Out:
#       corpus_name                                       raw_sentence  label  \
# 14592       CONAN  I musulmani violentano le nostre donne e vanno...      2
# 5633        CONAN  Le voile représente l'humeur politique des mus...      1
# 2587        CONAN  It is curious that almost all easter eggs are ...      1
# 7390        CONAN  L'islamophobie est bénéfique pour être banni p...      1
# 1535        CONAN  The only way we can fight Islam and Sharia is ...      1
# 4943        CONAN  Veiled women are subjected and forced to wear ...      1
# 6977        CONAN  Les musulmans ne sont pas tolérants envers les...      1
# 11738       CONAN  Gli islamici ricondurrano il nostro paese a st...      1
# 13964       CONAN  Gli arabi sono tutti terroristi e vogliono con...      1
# 6037        CONAN  Le voile représente l'humeur politique des mus...      1
#
#                                  clean_sentence_training  \
# 14592  I musulmani violentano le nostre donne e vanno...
# ...

# %%
corpus13.shape
# Out:
# (14988, 5)
