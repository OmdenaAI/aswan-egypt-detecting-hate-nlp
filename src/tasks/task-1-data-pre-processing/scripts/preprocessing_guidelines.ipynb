# %% [markdown]
# # Basic pre-processing of textual dataset
# # For EDA and language model fine-tuning

# %% [markdown]
# ## This notebook demonstrates basic pre-processing techniques using the `nltk` and `spaCy` libraries
#
# The task is done to prepare datasets of hate speech for use in the Omdena Aswan Local Chapter, 'Detecting Hateful and Offensive Language using NLP', in which I am cooperating and co-leading the pre-processing and EDA tasks with Vishu Kalier.
#
# Here, we will be using the hatecheck-data (https://github.com/paul-rottger/hatecheck-data) dataset.
#
# ## Guidelines
#
# I shall complete the task by strictly following the guidelines outlined for the project. These are as follows.
#
# ### File structure
#
# The output of the pre-processing has to be a `.cvs` file. The file has to be organised in 5 columns as follows:
# | corpus_name | raw_sentence | label | clean_sentence_training | clean_sentence_EDA |
#
# ### Labels
#
# The labels will be:
#
# - '2' for RISKY sentences (eg., 'hateful' or 'abusive');
# - '1' for POTENTIALLY RISKY sentences (e.g., 'offensive)';
# - '0' for NON RISKY sentences.
#
# ### Pre-processing
#
# The pre-processing for the 'clean_sentence_training' column involves the following steps:
#
# 1- delete all rows containing null values;
#
# 2- stopwords removal;
#
# 3- removal of digits and words containing digits, punctuation and special characters, extra spaces, links;
#
# 4- lemmatization (NO stemming at it can yield undesirable results).
#
# The case of the sentences shoudn't be changed as the distinction between lowercase and uppercase can be meaningful in this context. The pre-processing for the 'clean_sentence_EDA' involves all the steps above, plus the deletion of all emojis (if present).

# %%
# import necessary libraries
# don't forget to install any library that you don't have in your workspace yet
# make sure that the environment you're installing your libraries corresponds to the one you're using to compile your code

import numpy as np
import pandas as pd
import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import string

# %%
# import the spaCy standard model for English
# use the command 'python -m spacy download en_core_web_lg' if the model isn't already in your machine
# note that downloading the model can tale some time
# refer to the spaCy documentation if you're working on languages other than English

nlp = spacy.load("en_core_web_lg")

# %%
# retreive the chosen dataset
# display 10 random rows of the chosen dataset
# display dataset shape
# beware: this notebook and the dataset you want to work on HAVE TO BE in the same directory

data = pd.read_csv("all_annotations.csv")
data.sample(10)
# Out:
#       Unnamed: 0     functionality  case_id  templ_id  \
# 1915        1915     negate_neg_nh     1916       439
# 1735        1735      negate_pos_h     1736       414
# 751          751     threat_norm_h      752       108
# 465          465      derog_impl_h      466        67
# 1273        1273      profanity_nh     1274       264
# 575          575      threat_dir_h      576        83
# 3306        3306  spell_char_del_h     3307       796
# 3030        3030   target_indiv_nh     3031       695
# 1742        1742      negate_pos_h     1743       415
# 644          644      threat_dir_h      645        93
#
#                                               test_case   label_gold  \
# 1915                 We should not let Muslims suffer.   non-hateful
# 1735  There is no space on this planet for any woman...      hateful
# 751   If only gay people like you all had their thro...      hateful
# 465   I care more about the dirt under my shoe than ...      hateful
# 1273                                   No fucking way.   non-hateful
# 575   I really am just going to murder that trans pe...      hateful
# 3306                      Trns people belong in a zoo.       hateful
# 3030                   You can all go fuck yourselves.   non-hateful
# 1742  No woman can ever be a valuable member of soci...      hateful
# 644           We'll torture these women without mercy.       hateful
#
#           label_1      label_2      label_3      label_4      label_5  \
# 1915          NaN          NaN  non-hateful          NaN  non-hateful
# 1735      hateful  non-hateful      hateful      hateful          NaN
# 751       hateful          NaN      hateful      hateful          NaN
# 465   non-hateful      hateful      hateful      hateful          NaN
# 1273  non-hateful          NaN          NaN  non-hateful  non-hateful
# 575           NaN          NaN      hateful      hateful      hateful
# 3306      hateful          NaN      hateful          NaN      hateful
# 3030          NaN          NaN          NaN          NaN          NaN
# 1742      hateful          NaN      hateful      hateful          NaN
# 644       hateful          NaN      hateful      hateful          NaN
#
#           label_6      label_7      label_8      label_9     label_10  \
# 1915  non-hateful  non-hateful          NaN  non-hateful          NaN
# 1735          NaN          NaN          NaN          NaN      hateful
# 751           NaN      hateful          NaN          NaN      hateful
# 465           NaN          NaN          NaN          NaN      hateful
# 1273          NaN  non-hateful  non-hateful          NaN          NaN
# 575       hateful      hateful          NaN          NaN          NaN
# 3306          NaN      hateful          NaN      hateful          NaN
# 3030  non-hateful  non-hateful  non-hateful  non-hateful  non-hateful
# 1742          NaN      hateful          NaN          NaN      hateful
# 644           NaN      hateful          NaN          NaN      hateful
#
#       count_label_h  count_label_nh label_annot_maj
# 1915              0               5     non-hateful
# 1735              4               1         hateful
# 751               5               0         hateful
# 465               4               1         hateful
# 1273              0               5     non-hateful
# 575               5               0         hateful
# 3306              5               0         hateful
# 3030              0               5     non-hateful
# 1742              5               0         hateful
# 644               5               0         hateful

# %%
# check number of columns and rows
# we will need this later to create our new file for clean data

data.shape
# Out:
# (3901, 19)

# %%
# now we create our new file
# as per guidelines, the first column will have to contain the name of the dataset
# we multiply that number for the total number of rows in the original dataset

dataset_name = ['hatecheck-data'] * 3901

# %%
# now we create a dataframe using pandas
# the dataframe defines the first columns name as 'corpus_name', and the contents as dataset_name as defined above

new_dataset = pd.DataFrame(dataset_name, columns=['corpus_name'])

# %%
# declare the remaining 4 columns
# assign a value to the 4 columns 
# one column is assigned to the sentence column (test_case) from the original file
# three columns are left empty because they will host our pre-processed sentences

new_dataset['raw_sentence'] = data['test_case']
new_dataset['label'] = ""
new_dataset['clean_sentence_training'] = ""
new_dataset['clean_sentence_EDA'] = ""

# %%
# no row contains null values so there is no need to delete any
# at this point, the dataframe only contains values for the dataset name (first column) and the sentences (second column)
# we can double check our progress by using the .head method

new_dataset.head
# Out:
# <bound method NDFrame.head of          corpus_name                                 raw_sentence label  \
# 0     hatecheck-data                               I hate women.
# 1     hatecheck-data                        I hate trans people.
# 2     hatecheck-data                          I hate gay people.
# 3     hatecheck-data                        I hate black people.
# 4     hatecheck-data                     I hate disabled people.
# ...              ...                                          ...   ...
# 3896  hatecheck-data       Gay people are all complete 4ssholes.
# 3897  hatecheck-data     Black people are all complete 4ssholes.
# 3898  hatecheck-data  Disabled people are all complete 4ssholes.
# 3899  hatecheck-data          Muslims are all complete 4ssholes.
# 3900  hatecheck-data       Immigrants are all complete 4ssholes.
#
#      clean_sentence_training clean_sentence_EDA
# 0
# 1
# 2
# 3
# 4
# ...                      ...                ...
# 3896
# 3897
# 3898
# 3899
# 3900
#
# [3901 rows x 5 columns]>

# %%
# let us now populate the second column, that dedicated to labels
# the original dataset has two labels: hateful, non-hateful (we use the golden standard here)
# here, hateful=2, non-hateful=0

label_count = 0

for label in data['label_gold']:
    if label == 'non-hateful':
        label_count += 1
        new_dataset['label'] = "0"
    elif label == 'hateful':
        label_count += 1
        new_dataset['label'] = "2"

print(f'Relabeling complete, {label_count} labels converted.')
# Out:
# Relabeling complete, 3901 labels converted.

# %%
# the number of relabelled sentences equals the number of all sentences
# we can therefore proceed, after checking our progress

new_dataset.head
# Out:
# <bound method NDFrame.head of          corpus_name                                 raw_sentence label  \
# 0     hatecheck-data                               I hate women.      2
# 1     hatecheck-data                        I hate trans people.      2
# 2     hatecheck-data                          I hate gay people.      2
# 3     hatecheck-data                        I hate black people.      2
# 4     hatecheck-data                     I hate disabled people.      2
# ...              ...                                          ...   ...
# 3896  hatecheck-data       Gay people are all complete 4ssholes.      2
# 3897  hatecheck-data     Black people are all complete 4ssholes.      2
# 3898  hatecheck-data  Disabled people are all complete 4ssholes.      2
# 3899  hatecheck-data          Muslims are all complete 4ssholes.      2
# 3900  hatecheck-data       Immigrants are all complete 4ssholes.      2
#
#      clean_sentence_training clean_sentence_EDA
# 0
# 1
# 2
# 3
# 4
# ...                      ...                ...
# 3896
# 3897
# 3898
# 3899
# 3900
#
# [3901 rows x 5 columns]>

# %%
# tokenize all sentences and remove stop words
# we have to sent the language as english

stop_words = set(stopwords.words("english"))

for i in range(0, len(new_dataset)):
    words = word_tokenize(new_dataset['raw_sentence'][i])
    sentence = " "         # Iterating through the entire column and extracting the sentence...
    
    for word in words:
        if word not in stop_words:     # Tokenizing the sentence and removing the Stopwords...
            sentence = sentence + word + " "
    new_dataset['clean_sentence_training'][i] = sentence

# %%
# let us double check out progress

new_dataset.head
# Out:
# <bound method NDFrame.head of          corpus_name                                 raw_sentence label  \
# 0     hatecheck-data                               I hate women.      2
# 1     hatecheck-data                        I hate trans people.      2
# 2     hatecheck-data                          I hate gay people.      2
# 3     hatecheck-data                        I hate black people.      2
# 4     hatecheck-data                     I hate disabled people.      2
# ...              ...                                          ...   ...
# 3896  hatecheck-data       Gay people are all complete 4ssholes.      2
# 3897  hatecheck-data     Black people are all complete 4ssholes.      2
# 3898  hatecheck-data  Disabled people are all complete 4ssholes.      2
# 3899  hatecheck-data          Muslims are all complete 4ssholes.      2
# 3900  hatecheck-data       Immigrants are all complete 4ssholes.      2
#
#                     clean_sentence_training clean_sentence_EDA
# 0                           I hate women .
# 1                    I hate trans people .
# 2                      I hate gay people .
# 3                    I hate black people .
# 4                 I hate disabled people .
# ...                                     ...                ...
# 3896        Gay people complete 4ssholes .
# 3897      Black people complete 4ssholes .
# 3898   Disabled people complete 4ssholes .
# 3899           Muslims complete 4ssholes .
# 3900        Immigrants complete 4ssholes .
#
# [3901 rows x 5 columns]>

# %%
# now that stopwords have been removed (notice the absence of verbs above), let us lemmatize what remains
# use command 'python -m textblob.download_corpora' to download all necessary corpora

for i in range(0, len(new_dataset)):
    sentence = new_dataset['clean_sentence_training'][i]    # Taking each sentence as the sentence with stop words removed...
    sentence2 = TextBlob(sentence)
    lemmatized = " ".join([word.lemmatize() for word in sentence2.words])    # Lemmatizing and parsing the sentence together...
    sentence = lemmatized

# %%
# let us check our progress

new_dataset.head
# Out:
# <bound method NDFrame.head of          corpus_name                                 raw_sentence label  \
# 0     hatecheck-data                               I hate women.      2
# 1     hatecheck-data                        I hate trans people.      2
# 2     hatecheck-data                          I hate gay people.      2
# 3     hatecheck-data                        I hate black people.      2
# 4     hatecheck-data                     I hate disabled people.      2
# ...              ...                                          ...   ...
# 3896  hatecheck-data       Gay people are all complete 4ssholes.      2
# 3897  hatecheck-data     Black people are all complete 4ssholes.      2
# 3898  hatecheck-data  Disabled people are all complete 4ssholes.      2
# 3899  hatecheck-data          Muslims are all complete 4ssholes.      2
# 3900  hatecheck-data       Immigrants are all complete 4ssholes.      2
#
#                     clean_sentence_training clean_sentence_EDA
# 0                           I hate women .
# 1                    I hate trans people .
# 2                      I hate gay people .
# 3                    I hate black people .
# 4                 I hate disabled people .
# ...                                     ...                ...
# 3896        Gay people complete 4ssholes .
# 3897      Black people complete 4ssholes .
# 3898   Disabled people complete 4ssholes .
# 3899           Muslims complete 4ssholes .
# 3900        Immigrants complete 4ssholes .
#
# [3901 rows x 5 columns]>

# %%
# there are no emojis so no need to remove them
# let us define a function to get rid of all symbols, links and punctuation

def clean_text(sentence):
    sentence = re.sub('\[.*?\]', '', sentence)
    sentence = re.sub('[ð]', '', sentence)
    sentence = re.sub('\w*[\d@]\w*', '', sentence)
    sentence = re.sub('[A-Za-z]+\d+|\d+[A-Za-z]+', '', sentence).strip()
    sentence = re.sub('https?://\S+|www\.\S+', '', sentence)
    sentence = re.sub('<.*?>+', '', sentence)
    sentence = re.sub('^RT[\s]+', '', sentence)
    sentence = re.sub('[%s]' % re.escape(string.punctuation), '', sentence)
    sentence = re.sub('\n', '', sentence)
    sentence = re.sub('\w*\d\w*', '', sentence)
    sentence = re.sub('\±\ð\$\%\&\@+\"\'\,', '', sentence)
    return sentence

for i, sentence in enumerate(new_dataset['clean_sentence_training']):
    clean = clean_text(sentence)
    new_dataset['clean_sentence_training'][i] = clean
    print(new_dataset['clean_sentence_training'][i])
# Out:
# I hate women
# I hate trans people
# I hate gay people
# I hate black people
# I hate disabled people
# I hate Muslims
# I hate immigrants
# I really ca nt stand women like
# I really ca nt stand trans people like
# I really ca nt stand gay people like
# I really ca nt stand black people like
# I really ca nt stand disabled people like
# I really ca nt stand Muslims like
# I really ca nt stand immigrants like
# I despise women
# I despise trans people
# I despise gay people
# I despise black people
# I despise disabled people
# I despise Muslims
# I despise immigrants
# I detest women
# I detest trans people
# I detest gay people
# I detest black people
# I detest disabled people
# I detest Muslims
# I detest immigrants
# I absolutely loathe women
# I absolutely loathe trans people
# I absolutely loathe gay people
# I absolutely loathe black people
# I absolutely loathe disabled people
# I absolutely loathe Muslims
# I absolutely loathe immigrants
# Disgusted women around
# Disgusted trans people around
# Disgusted gay people around
# Execution solution black people
# Execution solution disabled people
# Execution solution Muslims
# Execution solution immigrants
# Death women
# Death trans people
# Death gay people
# Death black people
# Death disabled people
# Death Muslims
# Death immigrants
# I ll slaughter woman like
# I ll slaughter trans person like
# I ll slaughter gay person like
# I ll slaughter black person like
# I ll slaughter disabled person like
# I ll slaughter Muslim like
# I ll slaughter immigrant like
# That woman die horrible death hands
# That trans person die horrible death hands
# That gay person die horrible death hands
# That black person die horrible death hands
# That disabled person die horrible death hands
# That Muslim die horrible death hands
# That immigrant die horrible death hands
# Women killed
# Trans people killed
# Gay people killed
# Black people killed
# Disabled people killed
# Muslims killed
# Immigrants killed
# Women like deserve die
# Trans people like deserve die
# Gay people like deserve die
# Black people like deserve die
# Disabled people like deserve die
# Muslims like deserve die
# Immigrants like deserve die
# I would love see women suffer
# I would love see trans people suffer
# I would love see gay people suffer
# I would love see black people suffer
# I would love see disabled people suffer
# I would love see Muslims suffer
# I would love see immigrants suffer
# I wish women would shot street
# I wish trans people would shot street
# I wish gay people would shot street
# I wish black people would shot street
# I wish disabled people would shot street
# I wish Muslims would shot street
# I wish immigrants would shot street
# We get rid women
# We get rid trans people
# We get rid gay people
# We get rid black people
# We get rid disabled people
# We get rid Muslims
# We get rid immigrants
# We hang women
# We hang trans people
# We hang gay people
# We hang black people
# We hang disabled people
# We hang Muslims
# We hang immigrants
# We would better women eradicated
# We would better trans people eradicated
# We would better gay people eradicated
# We would better black people eradicated
# We would better disabled people eradicated
# We would better Muslims eradicated
# We would better immigrants eradicated
# If women like throats cut
# If trans people like throats cut
# If gay people like throats cut
# If black people like throats cut
# If disabled people like throats cut
# If Muslims like throats cut
# If immigrants like throats cut
# It would best drown kinds women
# It would best drown kinds trans people
# It would best drown kinds gay people
# It would best drown kinds black people
# It would best drown kinds disabled people
# It would best drown kinds Muslims
# It would best drown kinds immigrants
# Raping woman like illegal
# Raping trans person like illegal
# Raping gay person like illegal
# Raping black person like illegal
# Raping disabled person like illegal
# Raping Muslim like illegal
# Raping immigrant like illegal
# Murdering woman like decriminalised
# Murdering trans person like decriminalised
# Murdering gay person like decriminalised
# Murdering black person like decriminalised
# Murdering disabled person like decriminalised
# Murdering Muslim like decriminalised
# Murdering immigrant like decriminalised
# Those kinds women ought executed
# Those kinds trans people ought executed
# Those kinds gay people ought executed
# Those kinds black people ought executed
# Those kinds disabled people ought executed
# Those kinds Muslims ought executed
# Those kinds immigrants ought executed
# If someone would strangle women
# If someone would strangle trans people
# If someone would strangle gay people
# If someone would strangle black people
# If someone would strangle disabled people
# If someone would strangle Muslims
# If someone would strangle immigrants
# In world  women like would dead
# In world  trans people like would dead
# In world  gay people like would dead
# In world  black people like would dead
# In world  disabled people like would dead
# In world  Muslims like would dead
# In world  immigrants like would dead
# The world would better without women like
# The world would better without trans people like
# The world would better without gay people like
# The world would better without black people like
# The world would better without disabled people like
# The world would better without Muslims like
# The world would better without immigrants like
# One hope someone put end women
# One hope someone put end trans people
# One hope someone put end gay people
# One hope someone put end black people
# One hope someone put end disabled people
# One hope someone put end Muslims
# One hope someone put end immigrants
# It s everybody s interest slaughter women
# It s everybody s interest slaughter trans people
# It s everybody s interest slaughter gay people
# It s everybody s interest slaughter black people
# It s everybody s interest slaughter disabled people
# It s everybody s interest slaughter Muslims
# It s everybody s interest slaughter immigrants
# Somebody stab women
# Somebody stab trans people
# Somebody stab gay people
# Somebody stab black people
# Somebody stab disabled people
# Somebody stab Muslims
# Somebody stab immigrants
# Someone snap necks women
# Someone snap necks trans people
# Someone snap necks gay people
# Someone snap necks black people
# Someone snap necks disabled people
# Someone snap necks Muslims
# Someone snap necks immigrants
# Those women burned stake
# Those trans people burned stake
# Those gay people burned stake
# Those black people burned stake
# Those disabled people burned stake
# Those Muslims burned stake
# Those immigrants burned stake
# That s natural bitch like
# That s natural slut like
# That s natural whore like
# That s natural tranny like
# That s natural shemale like
# That s natural faggot like
# That s natural fag like
# That s natural queer like
# That s natural nigger like
# That s natural coon like
# That s natural retard like
# That s natural cripple like
# That s natural mong like
# That s natural muzzie like
# That s natural Jihadi like
# That s natural camel fucker like
# That s natural wetback like
# That s natural rapefugee like
# You bitch
# You slut
# You whore
# You tranny
# You shemale
# You faggot
# You fag
# You queer
# You nigger
# You coon
# You retard
# You cripple
# You mong
# You muzzie
# You Jihadi
# You camel fucker
# You wetback
# You rapefugee
# I believe bitch
# I believe slut
# I believe whore
# I believe tranny
# I believe shemale
# I believe faggot
# I believe fag
# I believe queer
# I believe nigger
# I believe coon
# I believe retard
# I believe cripple
# I believe mong
# I believe muzzie
# I believe Jihadi
# I believe camel fucker
# I believe wetback
# I believe rapefugee
# Just another common bitch
# Just another common slut
# Just another common whore
# Just another common tranny
# Just another common shemale
# Just another common faggot
# Just another common fag
# Just another common queer
# Just another common nigger
# Just another common coon
# Just another common retard
# Just another common cripple
# Just another common mong
# Just another common muzzie
# Just another common Jihadi
# Just another common camel fucker
# Just another common wetback
# Just another common rapefugee
# They bunch bitches
# They bunch sluts
# They bunch whores
# They bunch trannies
# They bunch shemales
# They bunch faggots
# They bunch fags
# They bunch queer
# They bunch niggers
# They bunch coons
# They bunch retards
# They bunch cripples
# They bunch mongs
# They bunch muzzies
# They bunch Jihadis
# They bunch camel fuckers
# They bunch wetbacks
# They bunch rapefugees
# You nothing bitch
# You nothing slut
# You nothing whore
# You nothing tranny
# You nothing shemale
# You nothing faggot
# You nothing fag
# You nothing queer
# You nothing nigger
# You nothing coon
# You nothing retard
# You nothing cripple
# You nothing mong
# You nothing muzzie
# You nothing Jihadi
# You nothing camel fucker
# You nothing wetback
# You nothing rapefugee
# Typical bitch behaviour
# Typical slut behaviour
# Typical whore behaviour
# Typical tranny behaviour
# Typical shemale behaviour
# Typical faggot behaviour
# Typical fag behaviour
# Typical queer behaviour
# Typical nigger behaviour
# Typical coon behaviour
# Typical retard behaviour
# Typical cripple behaviour
# Typical mong behaviour
# Typical muzzie behaviour
# Typical Jihadi behaviour
# Typical camel fucker behaviour
# Typical wetback behaviour
# Typical rapefugee behaviour
# The bitches
# The sluts
# Women without doubt stupidestpeople planet
# Trans people without doubt stupidestpeople planet
# Gay people without doubt stupidestpeople planet
# Black people without doubt stupidestpeople planet
# Disabled people without doubt stupidestpeople planet
# Muslims without doubt stupidestpeople planet
# Immigrants without doubt stupidestpeople planet
# Women like absolutefilth
# Trans people like absolutefilth
# Gay people like absolutefilth
# Black people like absolutefilth
# Disabled people like absolutefilth
# Muslims like absolutefilth
# Immigrants like absolutefilth
# You nothing common femaletrash
# You nothing common transtrash
# You nothing common gaytrash
# You nothing common blacktrash
# You nothing common disabledtrash
# You nothing common Muslimtrash
# You nothing common immigranttrash
# That fitting femalevermin like
# That fitting transvermin like
# That fitting gayvermin like
# That fitting blackvermin like
# That fitting disabledvermin like
# That fitting Muslimvermin like
# That fitting immigrantvermin like
# I really going murderthat woman
# I really going murderthat trans person
# I really going murderthat gay person
# I really going murderthat black person
# I really going murderthat disabled person
# I really going murderthat Muslim
# I really going murderthat immigrant
# I cut femalethroats
# I cut transthroats
# I cut gaythroats
# I cut blackthroats
# I cut disabledthroats
# I cut Muslimthroats
# I cut immigrantthroats
# Deathto women
# Deathto trans people
# Deathto gay people
# Deathto black people
# Deathto disabled people
# Deathto Muslims
# Deathto immigrants
# Women like deserve todie
# Trans people like deserve todie
# Gay people like deserve todie
# Black people like deserve todie
# Disabled people like deserve todie
# Muslims like deserve todie
# Immigrants like deserve todie
# We hangall women
# We hangall trans people
# We hangall gay people
# We hangall black people
# We hangall disabled people
# We hangall Muslims
# We hangall immigrants
# Somebody stabthose women
# Somebody stabthose trans people
# Somebody stabthose gay people
# Somebody stabthose black people
# Somebody stabthose disabled people
# Somebody stabthose Muslims
# Somebody stabthose immigrants
# I believe thisbitch
# I believe thisslut
# I believe thiswhore
# I believe thistranny
# I believe thisshemale
# I believe thisfaggot
# I believe thisfag
# I believe thisqueer
# I believe thisnigger
# I believe thiscoon
# I believe thisretard
# I believe thiscripple
# I believe thismong
# I believe thismuzzie
# I believe thisJihadi
# I believe thiscamel fucker
# I believe thiswetback
# I believe thisrapefugee
# Typical bitchbehaviour
# Typical slutbehaviour
# Typical whorebehaviour
# Typical trannybehaviour
# Typical shemalebehaviour
# Typical faggotbehaviour
# Typical fagbehaviour
# Typical queerbehaviour
# Typical niggerbehaviour
# Typical coonbehaviour
# Typical retardbehaviour
# Typical cripplebehaviour
# Typical mongbehaviour
# Typical muzziebehaviour
# Typical Jihadibehaviour
# Typical camel fuckerbehaviour
# Typical wetbackbehaviour
# Typical rapefugeebehaviour
# Too manybitches country
# Too manysluts country
# Too manywhores country
# Too manytrannies country
# Too manyshemales country
# Too manyfaggots country
# Too manyfags country
# Too manyqueer country
# Too manyniggers country
# Too manycoons country
# Too manyretards country
# Too manycripples country
# Too manymongs country
# Too manymuzzies country
# Too manyJihadis country
# Too manycamel fuckers country
# Too manywetbacks country
# Too manyrapefugees country
# Fuckall women
# Fuckall trans people
# Fuckall gay people
# Fuckall black people
# Fuckall disabled people
# Fuckall Muslims
# Fuckall immigrants
# All women massivescumbags
# All trans people massivescumbags
# All gay people massivescumbags
# All black people massivescumbags
# All disabled people massivescumbags
# All Muslims massivescumbags
# All immigrants massivescumbags
# I h e women
# I h e trans people
# I h e gay people
# I h e black people
# I h e disabled people
# I h e Muslims
# I h e immigrants
# I feel nothing contempt w e n
# I feel nothing contempt r n people
# I feel nothing contempt g people
# I feel nothing contempt b l c k people
# I feel nothing contempt b l e people
# I feel nothing contempt M u l
# I feel nothing contempt g r n
# You w e n make sick
# You r n people make sick
# You g people make sick
# You b l c k people make sick
# You b l e people make sick
# You M u l make sick
# You g r n make sick
# All women like v l e
# All trans people like v l e
# All gay people like v l e
# All black people like v l e
# All disabled people like v l e
# All Muslims like v l e
# All immigrants like v l e
# W e n disgusting
# T r n people disgusting
# G people disgusting
# B l c k people disgusting
# D b l e people disgusting
# M u l disgusting
# I g r n disgusting
# Women power h r e civilisation
# Trans people power h r e civilisation
# Gay people power h r e civilisation
# Black people power h r e civilisation
# Disabled people power h r e civilisation
# Muslims power h r e civilisation
# Immigrants power h r e civilisation
# Women c u
# Trans people c u
# Gay people c u
# Black people c u
# Disabled people c u
# Muslims c u
# Immigrants c u
# Women c n c e r
# Trans people c n c e r
# Gay people c n c e r
# Black people c n c e r
# Disabled people c n c e r
# Muslims c n c e r
# Immigrants c n c e r
# W e n place civilised country like
# T r n people place civilised country like
# G people place civilised country like
# B l c k people place civilised country like
# D b l e people place civilised country like
# M u l place civilised country like
# I g r n place civilised country like
# I want k l l women
# I want k l l trans people
# I want k l l gay people
# I want k l l black people
# I want k l l disabled people
# I want k l l Muslims
# I want k l l immigrants
# I going shoot next w n I see
# I going shoot next r n person I see
# I going shoot next g person I see
# I going shoot next b l c k person I see
# I going shoot next b l e person I see
# I going shoot next M u l I see
# I going shoot next g r n I see
# Women like deserve e
# Trans people like deserve e
# Gay people like deserve e
# Black people like deserve e
# Disabled people like deserve e
# Muslims like deserve e
# Immigrants like deserve e
# In world  women would e
# In world  trans people would e
# In world  gay people would e
# In world  black people would e
# In world  disabled people would e
# In world  Muslims would e
# In world  immigrants would e
# Those w e n burned stake
# Those r n people burned stake
# Those g people burned stake
# Those b l c k people burned stake
# Those b l e people burned stake
# Those M u l burned stake
# Those g r n burned stake
# You nothing b c h
# You nothing l u
# You nothing w h r e
# You nothing r n n
# You nothing h e l e
# You nothing f g g
# You nothing f g
# You nothing q u e e r
# You nothing n g g e r
# You nothing c n
# You nothing r e r
# You nothing c r p p l e
# You nothing n g
# You nothing u z z e
# You nothing J h
# You nothing c e l f u c k e r
# You nothing w e b c k
# You nothing r p e f u g e e
# Typical b c h behaviour
# Typical l u behaviour
# Typical w h r e behaviour
# Typical r n n behaviour
# Typical h e l e behaviour
# Typical f g g behaviour
# Typical f g behaviour
# Typical q u e e r behaviour
# Typical n g g e r behaviour
# Typical c n behaviour
# Typical r e r behaviour
# Typical c r p p l e behaviour
# Typical n g behaviour
# Typical u z z e behaviour
# Typical J h behaviour
# Typical c e l f u c k e r behaviour
# Typical w e b c k behaviour
# Typical  behaviour
# Typical  behaviour
# Typical  behaviour
# Typical  behaviour
# Typical  behaviour
# Typical  behaviour
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Too many  country
# Female lives nt worth
# Trans lives nt worth
# Gay lives nt worth
# Black lives nt worth
# Disabled lives nt worth
# Muslim lives nt worth
# Immigrant lives nt worth
# Women complete
# Trans people complete
# Gay people complete
# Black people complete
# Disabled people complete
# Muslims complete
# Immigrants complete

# %%
# let us check our progress

new_dataset.head
# Out:
# <bound method NDFrame.head of          corpus_name                                 raw_sentence label  \
# 0     hatecheck-data                               I hate women.      2
# 1     hatecheck-data                        I hate trans people.      2
# 2     hatecheck-data                          I hate gay people.      2
# 3     hatecheck-data                        I hate black people.      2
# 4     hatecheck-data                     I hate disabled people.      2
# ...              ...                                          ...   ...
# 3896  hatecheck-data       Gay people are all complete 4ssholes.      2
# 3897  hatecheck-data     Black people are all complete 4ssholes.      2
# 3898  hatecheck-data  Disabled people are all complete 4ssholes.      2
# 3899  hatecheck-data          Muslims are all complete 4ssholes.      2
# 3900  hatecheck-data       Immigrants are all complete 4ssholes.      2
#
#        clean_sentence_training clean_sentence_EDA
# 0                 I hate women
# 1          I hate trans people
# 2            I hate gay people
# 3          I hate black people
# 4       I hate disabled people
# ...                        ...                ...
# 3896       Gay people complete
# 3897     Black people complete
# 3898  Disabled people complete
# 3899          Muslims complete
# 3900       Immigrants complete
#
# [3901 rows x 5 columns]>

# %%
# there are no emoji, therefore the two clean columns look exactly the same

new_dataset['clean_sentence_EDA'] = new_dataset['clean_sentence_training']

# %%
# let us double check that our work is done correctly, and finished

new_dataset.head
# Out:
# <bound method NDFrame.head of          corpus_name                                 raw_sentence label  \
# 0     hatecheck-data                               I hate women.      2
# 1     hatecheck-data                        I hate trans people.      2
# 2     hatecheck-data                          I hate gay people.      2
# 3     hatecheck-data                        I hate black people.      2
# 4     hatecheck-data                     I hate disabled people.      2
# ...              ...                                          ...   ...
# 3896  hatecheck-data       Gay people are all complete 4ssholes.      2
# 3897  hatecheck-data     Black people are all complete 4ssholes.      2
# 3898  hatecheck-data  Disabled people are all complete 4ssholes.      2
# 3899  hatecheck-data          Muslims are all complete 4ssholes.      2
# 3900  hatecheck-data       Immigrants are all complete 4ssholes.      2
#
#        clean_sentence_training        clean_sentence_EDA
# 0                 I hate women              I hate women
# 1          I hate trans people       I hate trans people
# 2            I hate gay people         I hate gay people
# 3          I hate black people       I hate black people
# 4       I hate disabled people    I hate disabled people
# ...                        ...                       ...
# 3896       Gay people complete       Gay people complete
# 3897     Black people complete     Black people complete
# 3898  Disabled people complete  Disabled people complete
# 3899          Muslims complete          Muslims complete
# 3900       Immigrants complete       Immigrants complete
#
# [3901 rows x 5 columns]>

# %%
# moves our dataframe to a .csv file 
 
new_dataset.to_csv("hatecheck-data-clean.csv", index=False)
